# %%
import random

def word():
    l=["wikipedia","pneumonia","encylopedia","manifestation","pandemic","harbinger"]
    ch=random.choice(l)
    return ch.upper()

def blanks(w):
    return("_ "*len(w))



def hangman():
    h=[""" 
    ------
    |     |
    |     O
    |
    |
    |
    |
    --------
    """,
    """
    ------
    |     |
    |     O
    |     |
    |     
    |
    |
    --------
    """,
    """
    ------
    |     |
    |     O
    |     |
    |     |
    |
    |
    --------
    """,
    
    """
    ------
    |     |
    |     O
    |    \|
    |     |
    |      
    |
    --------
    """,
    
    """
    ------
    |     |
    |     O
    |    \|/
    |     |
    |      
    |
    --------
    """,
    """
    ------
    |     |
    |     O
    |    \|/
    |     |
    |    /
    |
    --------
    """,
    """
    ------
    |     |
    |     O
    |    \|/
    |     |
    |    / \ |
    |
    --------
    """
   ]
    return h
        
        
        
        
        
        
print("Welcome to HANGMAN GAME")
print("WORD TO BE GUESSED")
w=word()
b=blanks(w)
print(b)
l_blank=b.split(" ")

ha=hangman()
t=0
s=""
while True:
    n=input("Guess a letter?")
   
    if n.upper() in list(s):
        print("choose another letter,already choosen")
        continue
    else:
        if n.upper() in list(w):
            print("correct guess")
            index=[i for i,l in enumerate(w) if l==n.upper()]
        
            for i in index:
                l_blank[i]=n.upper()
                s=" ".join(l_blank)
            print(s)
        else:
            print(ha[t])
            if(t<7):
                print(" you guessed it wrong ,please try again!!")
                t+=1
            if(t==7):
                print("Man Hanged! GAME OVER")
                break
        
        s1="".join(l_blank)
        if(s1==w):
            print("No. Of tries done:",t)
            break
# Out:
# Welcome to HANGMAN GAME
# WORD TO BE GUESSED
# _ _ _ _ _ _ _ _ _
# Guess a letter?e
# correct guess
# _ _ E _ _ _ _ _ _
# Guess a letter?e
# choose another letter,already choosen
# Guess a letter?p
# correct guess
# P _ E _ _ _ _ _ _
# Guess a letter?n
# correct guess
# P N E _ _ _ N _ _
# Guess a letter?r
#
#     ------
#     |     |
#     |     O
#     |
#     |
#     |
#     |
#     --------
#
#  you guessed it wrong ,please try again!!
# Guess a letter?p
# choose another letter,already choosen
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-42577a3f990f> in <module>
#     103 s=""
#     104 while True:
# --> 105     n=input("Guess a letter?")
#     106
#     107     if n.upper() in list(s):
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
